# %% [markdown]
# # 앤스콤 데이터 집합 불러오기

# %%
import seaborn as sns

# %%
anscombe = sns.load_dataset("anscombe")
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
type(anscombe)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # matplotlib 라이브러리로 간단한 그래프 그리기

# %%
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']

# %%
dataset_1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
plt.plot(dataset_1['x'], dataset_1['y'])

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %%
dataset_1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %% [markdown]
# # 한 번에 4개의 그래프 그리기

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
frame = plt.figure()
axes1 = frame.add_subplot(2, 2, 1)
axes2 = frame.add_subplot(2, 2, 2)
axes3 = frame.add_subplot(2, 2, 3)
axes4 = frame.add_subplot(2, 2, 4)

# %%
axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

# %%
frame

# %%
axes1.set_title('dataset_1')
axes2.set_title('dataset_2')
axes3.set_title('dataset_3')
axes4.set_title('dataset_4')
# Out:
# Text(0.5,1,'dataset_4')

# %%
frame

# %%
frame.suptitle('<Anscombe Data>')
# Out:
# Text(0.5,0.98,'<Anscombe Data>')

# %%
frame

# %%
frame.tight_layout()
frame

# %% [markdown]
# # 기초 그래프 그리기 - 히스토그램, 산점도, 박스 그래프

# %%
tips = sns.load_dataset('tips')

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
fig = plt.figure()

# %%
X1 = fig.add_subplot(1, 1, 1)

# %%
fig

# %%
X1.hist(tips['total_bill'], bins=10)
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <a list of 10 Patch objects>)

# %%
X1.set_title('Histogram of Total Bill')
# Out:
# Text(0.5,1,'Histogram of Total Bill')

# %%
X1

# %%
fig

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data = {'A': ['anne', 'bero', 'candy'], 'B' : [1, 2, 3], 'C': ['test', 'train', 'test']}

# %%
data
# Out:
# {'A': ['anne', 'bero', 'candy'],
#  'B': [1, 2, 3],
#  'C': ['test', 'train', 'test']}

# %%
import pandas as pd

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame
# Out:
#        A  B      C
# 0   anne  1   test
# 1   bero  2  train
# 2  candy  3   test

# %%
pd.Timestamp('19951021')
# Out:
# Timestamp('1995-10-21 00:00:00')

# %%
data_frame.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
data_frame.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
data_frame.values
# Out:
# array([['anne', 1, 'test'],
#        ['bero', 2, 'train'],
#        ['candy', 3, 'test']], dtype=object)

# %%
data_frame.T
# Out:
#       0      1      2
# A  anne   bero  candy
# B     1      2      3
# C  test  train   test

# %%
data_frame
# Out:
#        A  B      C
# 0   anne  1   test
# 1   bero  2  train
# 2  candy  3   test

# %%
data_frame.sort_values(by='C')
# Out:
#        A  B      C
# 0   anne  1   test
# 2  candy  3   test
# 1   bero  2  train

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.sort_values(by='tip').head()
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2
# 111        7.25  1.00  Female     No  Sat  Dinner     1
# 0         16.99  1.01  Female     No  Sun  Dinner     2

# %%
tips['total_bill'].head()
# Out:
# 0    16.99
# 1    10.34
# 2    21.01
# 3    23.68
# 4    24.59
# Name: total_bill, dtype: float64

# %%
tips[tips['total_bill'] <= 10]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 30         9.55  1.45    Male     No   Sat  Dinner     2
# 43         9.68  1.32    Male     No   Sun  Dinner     2
# 53         9.94  1.56    Male     No   Sun  Dinner     2
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 126        8.52  1.48    Male     No  Thur   Lunch     2
# 135        8.51  1.25  Female     No  Thur   Lunch     2
# 145        8.35  1.50  Female     No  Thur   Lunch     2
# 148        9.78  1.73    Male     No  Thur   Lunch     2
# 149        7.51  2.00    Male     No  Thur   Lunch     2
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2
# 195        7.56  1.44    Male     No  Thur   Lunch     2
# ...

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips['time'].unique()
# Out:
# [Dinner, Lunch]
# Categories (2, object): [Dinner, Lunch]

# %%
tips[tips['time'] == 'Lunch'].head()
# Out:
#     total_bill   tip   sex smoker   day   time  size
# 77       27.20  4.00  Male     No  Thur  Lunch     4
# 78       22.76  3.00  Male     No  Thur  Lunch     2
# 79       17.29  2.71  Male     No  Thur  Lunch     2
# 80       19.44  3.00  Male    Yes  Thur  Lunch     2
# 81       16.66  3.40  Male     No  Thur  Lunch     2

# %%
len(tips[tips['time'] == 'Lunch'])
# Out:
# 68

# %%
len(tips[tips['time'] == 'Dinner'])
# Out:
# 176

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.loc[3:8, ['tip', 'time']]
# Out:
#     tip    time
# 3  3.31  Dinner
# 4  3.61  Dinner
# 5  4.71  Dinner
# 6  2.00  Dinner
# 7  3.12  Dinner
# 8  1.96  Dinner

# %%
tips.loc[1:5]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4

# %%
tips.loc[2:4, ['day', 'size']]
# Out:
#    day  size
# 2  Sun     3
# 3  Sun     2
# 4  Sun     4

# %%
tips.loc[129:143]
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 129       22.82  2.18    Male     No  Thur  Lunch     3
# 130       19.08  1.50    Male     No  Thur  Lunch     2
# 131       20.27  2.83  Female     No  Thur  Lunch     2
# 132       11.17  1.50  Female     No  Thur  Lunch     2
# 133       12.26  2.00  Female     No  Thur  Lunch     2
# 134       18.26  3.25  Female     No  Thur  Lunch     2
# 135        8.51  1.25  Female     No  Thur  Lunch     2
# 136       10.33  2.00  Female     No  Thur  Lunch     2
# 137       14.15  2.00  Female     No  Thur  Lunch     2
# 138       16.00  2.00    Male    Yes  Thur  Lunch     2
# 139       13.16  2.75  Female     No  Thur  Lunch     2
# 140       17.47  3.50  Female     No  Thur  Lunch     2
# 141       34.30  6.70    Male     No  Thur  Lunch     6
# 142       41.19  5.00    Male     No  Thur  Lunch     5
# 143       27.05  5.00  Female     No  Thur  Lunch     6

# %%
tips.loc[143]
# Out:
# total_bill     27.05
# tip                5
# sex           Female
# smoker            No
# day             Thur
# time           Lunch
# size               6
# Name: 143, dtype: object

# %%
tips.loc[5:10, ['tip', 'time']]
# Out:
#      tip    time
# 5   4.71  Dinner
# 6   2.00  Dinner
# 7   3.12  Dinner
# 8   1.96  Dinner
# 9   3.23  Dinner
# 10  1.71  Dinner

# %%
tips.loc[5:10, ['sex', 'smoker']]
# Out:
#      sex smoker
# 5   Male     No
# 6   Male     No
# 7   Male     No
# 8   Male     No
# 9   Male     No
# 10  Male     No

# %%
tips.iloc[9]
# Out:
# total_bill     14.78
# tip             3.23
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 9, dtype: object

# %%
tips.loc[9]
# Out:
# total_bill     14.78
# tip             3.23
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 9, dtype: object

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.iloc[[2, 4, 6], 3:6]
# Out:
#   smoker  day    time
# 2     No  Sun  Dinner
# 4     No  Sun  Dinner
# 6     No  Sun  Dinner

# %%
tips.iloc[[2, 4, 6], [1, 3, 5]]
# Out:
#     tip smoker    time
# 2  3.50     No  Dinner
# 4  3.61     No  Dinner
# 6  2.00     No  Dinner

# %%
tips.iloc[[2, 4, 6], :]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2

# %%
tips.iloc[:, 3:5].head()
# Out:
#   smoker  day
# 0     No  Sun
# 1     No  Sun
# 2     No  Sun
# 3     No  Sun
# 4     No  Sun

# %%
tips[tips['tip'] >= 5]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 39        31.27   5.00    Male     No   Sat  Dinner     3
# 44        30.40   5.60    Male     No   Sun  Dinner     4
# 46        22.23   5.00    Male     No   Sun  Dinner     2
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 52        34.81   5.20  Female     No   Sun  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 73        25.28   5.00  Female    Yes   Sat  Dinner     2
# 83        32.68   5.00    Male    Yes  Thur   Lunch     2
# 85        34.83   5.17  Female     No  Thur   Lunch     4
# 88        24.71   5.85    Male     No  Thur   Lunch     2
# 116       29.93   5.07    Male     No   Sun  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# ...

# %%
tips[tips['total_bill'] >= 40]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4

# %%
tips2 = tips.copy()

# %%
tips2['sleep'] = 4

# %%
tips2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  sleep
# 0       16.99  1.01  Female     No  Sun  Dinner     2      4
# 1       10.34  1.66    Male     No  Sun  Dinner     3      4
# 2       21.01  3.50    Male     No  Sun  Dinner     3      4
# 3       23.68  3.31    Male     No  Sun  Dinner     2      4
# 4       24.59  3.61  Female     No  Sun  Dinner     4      4

# %%
data = {'name' : ['CW', 'SW', 'KC', 'HS', 'HY', 'HR', 'YJ', 'SH', 'JS', 'SJ'], 
        'grade' : [2, 1, 4, 3, 2, 4, 3, 2, 5, 3], 
        'sex' : ['F', 'M', 'F', 'M', 'F', 'F', 'M', 'F', 'M', 'F'], 
        'age' : [ 15, 33, 24, 3, 26, 13, 7, 6, 15, 17]}

# %%
data
# Out:
# {'grade': [2, 1, 4, 3, 2, 4, 3, 2, 5, 3],
#  'name': ['CW', 'SW', 'KC', 'HS', 'HY', 'HR', 'YJ', 'SH', 'JS', 'SJ'],
#  'sex': ['F', 'M', 'F', 'M', 'F', 'F', 'M', 'F', 'M', 'F'],
#  'time': [15, 33, 24, 3, 26, 13, 7, 6, 15, 17]}

# %%
students = pd.DataFrame(data)

# %%
students
# Out:
#    grade name sex  time
# 0      2   CW   F    15
# 1      1   SW   M    33
# 2      4   KC   F    24
# 3      3   HS   M     3
# 4      2   HY   F    26
# 5      4   HR   F    13
# 6      3   YJ   M     7
# 7      2   SH   F     6
# 8      5   JS   M    15
# 9      3   SJ   F    17

# %%
students = pd.DataFrame(data, columns=['name', 'sex', 'age', 'grade'])

# %%
students
# Out:
#   name sex  age  grade
# 0   CW   F   15      2
# 1   SW   M   33      1
# 2   KC   F   24      4
# 3   HS   M    3      3
# 4   HY   F   26      2
# 5   HR   F   13      4
# 6   YJ   M    7      3
# 7   SH   F    6      2
# 8   JS   M   15      5
# 9   SJ   F   17      3

# %%
students.sort_values(by='age')
# Out:
#   name sex  age  grade
# 3   HS   M    3      3
# 7   SH   F    6      2
# 6   YJ   M    7      3
# 5   HR   F   13      4
# 0   CW   F   15      2
# 8   JS   M   15      5
# 9   SJ   F   17      3
# 2   KC   F   24      4
# 4   HY   F   26      2
# 1   SW   M   33      1

# %%
students.reindex(index=[9, 8, 7, 6, 5, 4, 3, 2, 1, 0])
# Out:
#   name sex  age  grade
# 9   SJ   F   17      3
# 8   JS   M   15      5
# 7   SH   F    6      2
# 6   YJ   M    7      3
# 5   HR   F   13      4
# 4   HY   F   26      2
# 3   HS   M    3      3
# 2   KC   F   24      4
# 1   SW   M   33      1
# 0   CW   F   15      2

# %%
import numpy as np

# %%
students['time'] = np.nan

# %%
students
# Out:
#   name sex  age  grade  time
# 0   CW   F   15      2   NaN
# 1   SW   M   33      1   NaN
# 2   KC   F   24      4   NaN
# 3   HS   M    3      3   NaN
# 4   HY   F   26      2   NaN
# 5   HR   F   13      4   NaN
# 6   YJ   M    7      3   NaN
# 7   SH   F    6      2   NaN
# 8   JS   M   15      5   NaN
# 9   SJ   F   17      3   NaN

# %%
students.loc[2:6, ['time']] = 5

# %%
students
# Out:
#   name sex  age  grade  time
# 0   CW   F   15      2   NaN
# 1   SW   M   33      1   NaN
# 2   KC   F   24      4   5.0
# 3   HS   M    3      3   5.0
# 4   HY   F   26      2   5.0
# 5   HR   F   13      4   5.0
# 6   YJ   M    7      3   5.0
# 7   SH   F    6      2   NaN
# 8   JS   M   15      5   NaN
# 9   SJ   F   17      3   NaN

# %%
students['weight'] = students['age'] * students['grade']
students
# Out:
#   name sex  age  grade  time  weight
# 0   CW   F   15      2   NaN      30
# 1   SW   M   33      1   NaN      33
# 2   KC   F   24      4   NaN      96
# 3   HS   M    3      3   NaN       9
# 4   HY   F   26      2   NaN      52
# 5   HR   F   13      4   NaN      52
# 6   YJ   M    7      3   NaN      21
# 7   SH   F    6      2   NaN      12
# 8   JS   M   15      5   NaN      75
# 9   SJ   F   17      3   NaN      51

# %%
students.loc[10] = np.nan
students
# Out:
#    name  sex  age  grade  time  weight  height
# 0    CW    F   15    2.0   NaN    30.0    60.0
# 1    SW    M   33    1.0   NaN    33.0    66.0
# 2    KC    F   24    4.0   NaN    96.0   192.0
# 3    HS    M    3    3.0   NaN     9.0    18.0
# 4    HY    F   26    2.0   NaN    52.0   104.0
# 5    HR    F   13    4.0   NaN    52.0   104.0
# 6    YJ    M    7    3.0   NaN    21.0    42.0
# 7    SH    F    6    2.0   NaN    12.0    24.0
# 8    JS    M   15    5.0   NaN    75.0   150.0
# 9    SJ    F   17    3.0   NaN    51.0   102.0
# 10  NaN  NaN  NaN    NaN   NaN     NaN     NaN

# %%
students = students.drop(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-228-a8bc27d5d5bb> in <module>()
# ----> 1 students = students.drop(10)
#       2 students
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# ...

# %%
students
# Out:
#   name sex age  grade  time  weight  height
# 0   CW   F  15    2.0   NaN    30.0    60.0
# 1   SW   M  33    1.0   NaN    33.0    66.0
# 2   KC   F  24    4.0   NaN    96.0   192.0
# 3   HS   M   3    3.0   NaN     9.0    18.0
# 4   HY   F  26    2.0   NaN    52.0   104.0
# 5   HR   F  13    4.0   NaN    52.0   104.0
# 6   YJ   M   7    3.0   NaN    21.0    42.0
# 7   SH   F   6    2.0   NaN    12.0    24.0
# 8   JS   M  15    5.0   NaN    75.0   150.0
# 9   SJ   F  17    3.0   NaN    51.0   102.0

# %%
students = students.drop('height', 1)
# df = df.drop("x2", 1) # axis = 1일때 세로축 삭제, 0일때 가로축 삭제
students
# Out:
#   name sex age  grade  time  weight
# 0   CW   F  15    2.0   NaN    30.0
# 1   SW   M  33    1.0   NaN    33.0
# 2   KC   F  24    4.0   NaN    96.0
# 3   HS   M   3    3.0   NaN     9.0
# 4   HY   F  26    2.0   NaN    52.0
# 5   HR   F  13    4.0   NaN    52.0
# 6   YJ   M   7    3.0   NaN    21.0
# 7   SH   F   6    2.0   NaN    12.0
# 8   JS   M  15    5.0   NaN    75.0
# 9   SJ   F  17    3.0   NaN    51.0

# %%
students.loc[10] = ['HK', 'F', 27, 6, 24, 55]

# %%
students
# Out:
#    name sex age  grade  time  weight
# 0    CW   F  15    2.0   NaN    30.0
# 1    SW   M  33    1.0   NaN    33.0
# 2    KC   F  24    4.0   NaN    96.0
# 3    HS   M   3    3.0   NaN     9.0
# 4    HY   F  26    2.0   NaN    52.0
# 5    HR   F  13    4.0   NaN    52.0
# 6    YJ   M   7    3.0   NaN    21.0
# 7    SH   F   6    2.0   NaN    12.0
# 8    JS   M  15    5.0   NaN    75.0
# 9    SJ   F  17    3.0   NaN    51.0
# 10   HK   F  27    6.0  24.0    55.0

# %%
students = students.drop(11)
students
# Out:
#   name sex age  grade  time  weight
# 0   CW   F  15    2.0   NaN    30.0
# 1   SW   M  33    1.0   NaN    33.0
# 2   KC   F  24    4.0   NaN    96.0
# 3   HS   M   3    3.0   NaN     9.0
# 4   HY   F  26    2.0   NaN    52.0
# 5   HR   F  13    4.0   NaN    52.0
# 6   YJ   M   7    3.0   NaN    21.0
# 7   SH   F   6    2.0   NaN    12.0
# 8   JS   M  15    5.0   NaN    75.0
# 9   SJ   F  17    3.0   NaN    51.0

# %%
students
# Out:
#    name sex age  grade  time  weight
# 0    CW   F  15    2.0   NaN    30.0
# 1    SW   M  33    1.0   NaN    33.0
# 2    KC   F  24    4.0   NaN    96.0
# 3    HS   M   3    3.0   NaN     9.0
# 4    HY   F  26    2.0   NaN    52.0
# 5    HR   F  13    4.0   NaN    52.0
# 6    YJ   M   7    3.0   NaN    21.0
# 7    SH   F   6    2.0   NaN    12.0
# 8    JS   M  15    5.0   NaN    75.0
# 9    SJ   F  17    3.0   NaN    51.0
# 10   HK   F  27    6.0  24.0    55.0

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(students['name'], students['age'], 'o')

# %%
plt.plot(students['sex'], students['age'], 'r')

# %%
students
# Out:
#    name sex age  grade  time  weight
# 0    CW   F  15    2.0   NaN    30.0
# 1    SW   M  33    1.0   NaN    33.0
# 2    KC   F  24    4.0   NaN    96.0
# 3    HS   M   3    3.0   NaN     9.0
# 4    HY   F  26    2.0   NaN    52.0
# 5    HR   F  13    4.0   NaN    52.0
# 6    YJ   M   7    3.0   NaN    21.0
# 7    SH   F   6    2.0   NaN    12.0
# 8    JS   M  15    5.0   NaN    75.0
# 9    SJ   F  17    3.0   NaN    51.0
# 10   HK   F  27    6.0  24.0    55.0

# %%
students.corr()
# Out:
#            grade  time    weight
# grade   1.000000   NaN  0.549264
# time         NaN   NaN       NaN
# weight  0.549264   NaN  1.000000

# %%
students['height'] = students['weight'] * 2

# %%
students
# Out:
#    name sex age  grade  time  weight  height
# 0    CW   F  15    2.0   NaN    30.0    60.0
# 1    SW   M  33    1.0   NaN    33.0    66.0
# 2    KC   F  24    4.0   NaN    96.0   192.0
# 3    HS   M   3    3.0   NaN     9.0    18.0
# 4    HY   F  26    2.0   NaN    52.0   104.0
# 5    HR   F  13    4.0   NaN    52.0   104.0
# 6    YJ   M   7    3.0   NaN    21.0    42.0
# 7    SH   F   6    2.0   NaN    12.0    24.0
# 8    JS   M  15    5.0   NaN    75.0   150.0
# 9    SJ   F  17    3.0   NaN    51.0   102.0
# 10   HK   F  27    6.0  24.0    55.0   110.0

# %%
import seaborn as sns

# %%
sns.distplot(students['height'])

# %%
sns.distplot(students['weight'])

# %%
students.sort_values(by='age')
# Out:
#    name sex age  grade  time  weight  height
# 3    HS   M   3    3.0   NaN     9.0    18.0
# 7    SH   F   6    2.0   NaN    12.0    24.0
# 6    YJ   M   7    3.0   NaN    21.0    42.0
# 5    HR   F  13    4.0   NaN    52.0   104.0
# 0    CW   F  15    2.0   NaN    30.0    60.0
# 8    JS   M  15    5.0   NaN    75.0   150.0
# 9    SJ   F  17    3.0   NaN    51.0   102.0
# 2    KC   F  24    4.0   NaN    96.0   192.0
# 4    HY   F  26    2.0   NaN    52.0   104.0
# 10   HK   F  27    6.0  24.0    55.0   110.0
# 1    SW   M  33    1.0   NaN    33.0    66.0

# %%
students.sort_values(by='age', ascending=False)
# Out:
#    name sex age  grade  time  weight  height
# 1    SW   M  33    1.0   NaN    33.0    66.0
# 10   HK   F  27    6.0  24.0    55.0   110.0
# 4    HY   F  26    2.0   NaN    52.0   104.0
# 2    KC   F  24    4.0   NaN    96.0   192.0
# 9    SJ   F  17    3.0   NaN    51.0   102.0
# 0    CW   F  15    2.0   NaN    30.0    60.0
# 8    JS   M  15    5.0   NaN    75.0   150.0
# 5    HR   F  13    4.0   NaN    52.0   104.0
# 6    YJ   M   7    3.0   NaN    21.0    42.0
# 7    SH   F   6    2.0   NaN    12.0    24.0
# 3    HS   M   3    3.0   NaN     9.0    18.0

# %%
students['age'].describe()
# Out:
# count     11.0
# unique    10.0
# top       15.0
# freq       2.0
# Name: age, dtype: float64

# %%
students['grade'].describe()
# Out:
# count    11.000000
# mean      3.181818
# std       1.470930
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       6.000000
# Name: grade, dtype: float64

# %%
students['sex'].value_counts()
# Out:
# F    7
# M    4
# Name: sex, dtype: int64

# %%
students['time'].dropna()
# Out:
# 10    24.0
# Name: time, dtype: float64

# %%
students
# Out:
#    name sex age  grade  time  weight  height
# 0    CW   F  15    2.0   NaN    30.0    60.0
# 1    SW   M  33    1.0   NaN    33.0    66.0
# 2    KC   F  24    4.0   NaN    96.0   192.0
# 3    HS   M   3    3.0   NaN     9.0    18.0
# 4    HY   F  26    2.0   NaN    52.0   104.0
# 5    HR   F  13    4.0   NaN    52.0   104.0
# 6    YJ   M   7    3.0   NaN    21.0    42.0
# 7    SH   F   6    2.0   NaN    12.0    24.0
# 8    JS   M  15    5.0   NaN    75.0   150.0
# 9    SJ   F  17    3.0   NaN    51.0   102.0
# 10   HK   F  27    6.0  24.0    55.0   110.0

# %%
plt.scatter(students['sex'], students['age'])
plt.xlabel('sex')
plt.ylabel('age')
# Out:
# Text(0,0.5,'age')

# %%
students['age'].mean()
# Out:
# 16.90909090909091

# %%
students['height'].max()
# Out:
# 192.0

# %%
students['weight'].min()
# Out:
# 9.0

# %%
students.groupby(['sex'])['weight'].mean()
# Out:
# sex
# F    49.714286
# M    34.500000
# Name: weight, dtype: float64

# %%
students.groupby(['sex'])['weight'].median()
# Out:
# sex
# F    52.0
# M    27.0
# Name: weight, dtype: float64

# %%
students['age'].plot()

# %%
students['age'].plot(kind='bar')
plt.title('graph_name')
plt.xlabel('number')
plt.ylabel('age')
# Out:
# Text(0,0.5,'age')

# %%
students['age']
# Out:
# 0     15
# 1     33
# 2     24
# 3      3
# 4     26
# 5     13
# 6      7
# 7      6
# 8     15
# 9     17
# 10    27
# Name: age, dtype: object

# %%
students.groupby(['sex'])['age'].plot(kind='bar')
# students.groupby(['sex'])['weight'].mean()
# Out:
# sex
# F    AxesSubplot(0.125,0.125;0.775x0.755)
# M    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: age, dtype: object

# %%
students.set_index('name', inplace=True)

# %%
students
# Out:
#      sex age  grade  time  weight  height
# name
# CW     F  15    2.0   NaN    30.0    60.0
# SW     M  33    1.0   NaN    33.0    66.0
# KC     F  24    4.0   NaN    96.0   192.0
# HS     M   3    3.0   NaN     9.0    18.0
# HY     F  26    2.0   NaN    52.0   104.0
# HR     F  13    4.0   NaN    52.0   104.0
# YJ     M   7    3.0   NaN    21.0    42.0
# SH     F   6    2.0   NaN    12.0    24.0
# JS     M  15    5.0   NaN    75.0   150.0
# SJ     F  17    3.0   NaN    51.0   102.0
# HK     F  27    6.0  24.0    55.0   110.0

# %%
students['weight'].plot(kind='bar')
plt.title('students_graph')
plt.xlabel('name')
plt.ylabel('weight')
# Out:
# Text(0,0.5,'weight')

# %%
students['age'].sort_values().plot(kind='bar')
plt.title('students_graph')
plt.xlabel('name')
plt.ylabel('age')
# Out:
# Text(0,0.5,'age')

# %%
students['age'].sort_values(ascending=False).plot(kind='bar')
plt.title('students_graph')
plt.xlabel('name')
plt.ylabel('age')
# Out:
# Text(0,0.5,'age')

# %%
students
# Out:
#      sex age  grade  time  weight  height
# name
# CW     F  15    2.0   NaN    30.0    60.0
# SW     M  33    1.0   NaN    33.0    66.0
# KC     F  24    4.0   NaN    96.0   192.0
# HS     M   3    3.0   NaN     9.0    18.0
# HY     F  26    2.0   NaN    52.0   104.0
# HR     F  13    4.0   NaN    52.0   104.0
# YJ     M   7    3.0   NaN    21.0    42.0
# SH     F   6    2.0   NaN    12.0    24.0
# JS     M  15    5.0   NaN    75.0   150.0
# SJ     F  17    3.0   NaN    51.0   102.0
# HK     F  27    6.0  24.0    55.0   110.0

# %%
students.loc[students['sex'] == 'M']
# Out:
#      sex age  grade  time  weight  height
# name
# SW     M  33    1.0   NaN    33.0    66.0
# HS     M   3    3.0   NaN     9.0    18.0
# YJ     M   7    3.0   NaN    21.0    42.0
# JS     M  15    5.0   NaN    75.0   150.0

# %%
students.loc[students['age'] >= 20]
# Out:
#      sex age  grade  time  weight  height
# name
# SW     M  33    1.0   NaN    33.0    66.0
# KC     F  24    4.0   NaN    96.0   192.0
# HY     F  26    2.0   NaN    52.0   104.0
# HK     F  27    6.0  24.0    55.0   110.0

# %%
students.loc[(students['age'] >= 20)&(students['age'] >= 24)]
# Out:
#      sex age  grade  time  weight  height
# name
# SW     M  33    1.0   NaN    33.0    66.0
# KC     F  24    4.0   NaN    96.0   192.0
# HY     F  26    2.0   NaN    52.0   104.0
# HK     F  27    6.0  24.0    55.0   110.0

# %%
students.drop('height', axis=1)
# Out:
#      sex age  grade  time  weight
# name
# CW     F  15    2.0   NaN    30.0
# SW     M  33    1.0   NaN    33.0
# KC     F  24    4.0   NaN    96.0
# HS     M   3    3.0   NaN     9.0
# HY     F  26    2.0   NaN    52.0
# HR     F  13    4.0   NaN    52.0
# YJ     M   7    3.0   NaN    21.0
# SH     F   6    2.0   NaN    12.0
# JS     M  15    5.0   NaN    75.0
# SJ     F  17    3.0   NaN    51.0
# HK     F  27    6.0  24.0    55.0

# %%
students
# Out:
#      sex age  grade  time  weight  height
# name
# CW     F  15    2.0   NaN    30.0    60.0
# SW     M  33    1.0   NaN    33.0    66.0
# KC     F  24    4.0   NaN    96.0   192.0
# HS     M   3    3.0   NaN     9.0    18.0
# HY     F  26    2.0   NaN    52.0   104.0
# HR     F  13    4.0   NaN    52.0   104.0
# YJ     M   7    3.0   NaN    21.0    42.0
# SH     F   6    2.0   NaN    12.0    24.0
# JS     M  15    5.0   NaN    75.0   150.0
# SJ     F  17    3.0   NaN    51.0   102.0
# HK     F  27    6.0  24.0    55.0   110.0

# %%
students[students['age'] >= 15].sort_values(by='grade')
# Out:
#      sex age  grade  time  weight  height
# name
# SW     M  33    1.0   NaN    33.0    66.0
# CW     F  15    2.0   NaN    30.0    60.0
# HY     F  26    2.0   NaN    52.0   104.0
# SJ     F  17    3.0   NaN    51.0   102.0
# KC     F  24    4.0   NaN    96.0   192.0
# JS     M  15    5.0   NaN    75.0   150.0
# HK     F  27    6.0  24.0    55.0   110.0

# %%
students['time'] = students['time'].mean()

# %%
students
# Out:
#      sex age  grade  time  weight  height
# name
# CW     F  15    2.0  24.0    30.0    60.0
# SW     M  33    1.0  24.0    33.0    66.0
# KC     F  24    4.0  24.0    96.0   192.0
# HS     M   3    3.0  24.0     9.0    18.0
# HY     F  26    2.0  24.0    52.0   104.0
# HR     F  13    4.0  24.0    52.0   104.0
# YJ     M   7    3.0  24.0    21.0    42.0
# SH     F   6    2.0  24.0    12.0    24.0
# JS     M  15    5.0  24.0    75.0   150.0
# SJ     F  17    3.0  24.0    51.0   102.0
# HK     F  27    6.0  24.0    55.0   110.0

# %%
students_n = students.pivot('sex', 'age', 'age')
students_n
# Out:
# age  3.0   6.0   7.0   13.0  15.0  17.0  24.0  26.0  27.0  33.0
# sex
# F     NaN   6.0   NaN  13.0  15.0  17.0  24.0  26.0  27.0   NaN
# M     3.0   NaN   7.0   NaN  15.0   NaN   NaN   NaN   NaN  33.0

# %%
students['job']=np.NAN
students
# Out:
#      sex   age  grade  time  weight  height  job
# name
# CW     F  15.0    2.0  24.0    30.0    60.0  NaN
# SW     M  33.0    1.0  24.0    33.0    66.0  NaN
# KC     F  24.0    4.0  24.0    96.0   192.0  NaN
# HS     M   3.0    3.0  24.0     9.0    18.0  NaN
# HY     F  26.0    2.0  24.0    52.0   104.0  NaN
# HR     F  13.0    4.0  24.0    52.0   104.0  NaN
# YJ     M   7.0    3.0  24.0    21.0    42.0  NaN
# SH     F   6.0    2.0  24.0    12.0    24.0  NaN
# JS     M  15.0    5.0  24.0    75.0   150.0  NaN
# SJ     F  17.0    3.0  24.0    51.0   102.0  NaN
# HK     F  27.0    6.0  24.0    55.0   110.0  NaN

# %%
pd.pivot_table(students, index=['sex'])
# Out:
#            age     grade     height  time     weight
# sex
# F    18.285714  3.285714  99.428571  24.0  49.714286
# M    14.500000  3.000000  69.000000  24.0  34.500000

# %%
pd.pivot_table(students, index=['sex', 'name'])
# Out:
#            age  grade  height  time  weight
# sex name
# F   CW    15.0    2.0    60.0  24.0    30.0
#     HK    27.0    6.0   110.0  24.0    55.0
#     HR    13.0    4.0   104.0  24.0    52.0
#     HY    26.0    2.0   104.0  24.0    52.0
#     KC    24.0    4.0   192.0  24.0    96.0
#     SH     6.0    2.0    24.0  24.0    12.0
#     SJ    17.0    3.0   102.0  24.0    51.0
# M   HS     3.0    3.0    18.0  24.0     9.0
#     JS    15.0    5.0   150.0  24.0    75.0
#     SW    33.0    1.0    66.0  24.0    33.0
#     YJ     7.0    3.0    42.0  24.0    21.0

# %%
new = pd.pivot_table(students, index=['sex', 'name'])
new
# Out:
#            age  grade  height  time  weight
# sex name
# F   CW    15.0    2.0    60.0  24.0    30.0
#     HK    27.0    6.0   110.0  24.0    55.0
#     HR    13.0    4.0   104.0  24.0    52.0
#     HY    26.0    2.0   104.0  24.0    52.0
#     KC    24.0    4.0   192.0  24.0    96.0
#     SH     6.0    2.0    24.0  24.0    12.0
#     SJ    17.0    3.0   102.0  24.0    51.0
# M   HS     3.0    3.0    18.0  24.0     9.0
#     JS    15.0    5.0   150.0  24.0    75.0
#     SW    33.0    1.0    66.0  24.0    33.0
#     YJ     7.0    3.0    42.0  24.0    21.0

# %%
new.plot()

# %%
new2 = pd.pivot_table(students, index=['sex'])
new2
new2.plot()

# %%
students['job'].isnull()
# Out:
# name
# CW    True
# SW    True
# KC    True
# HS    True
# HY    True
# HR    True
# YJ    True
# SH    True
# JS    True
# SJ    True
# HK    True
# Name: job, dtype: bool

# %%
students['job'].dropna()
# Out:
# Series([], Name: job, dtype: float64)

# %%
students
# Out:
#      sex   age  grade  time  weight  height  job
# name
# CW     F  15.0    2.0  24.0    30.0    60.0  NaN
# SW     M  33.0    1.0  24.0    33.0    66.0  NaN
# KC     F  24.0    4.0  24.0    96.0   192.0  NaN
# HS     M   3.0    3.0  24.0     9.0    18.0  NaN
# HY     F  26.0    2.0  24.0    52.0   104.0  NaN
# HR     F  13.0    4.0  24.0    52.0   104.0  NaN
# YJ     M   7.0    3.0  24.0    21.0    42.0  NaN
# SH     F   6.0    2.0  24.0    12.0    24.0  NaN
# JS     M  15.0    5.0  24.0    75.0   150.0  NaN
# SJ     F  17.0    3.0  24.0    51.0   102.0  NaN
# HK     F  27.0    6.0  24.0    55.0   110.0  NaN

# %%
students['healthy'] = np.NAN
students
# Out:
# name
# CW          60.0
# SW          66.0
# KC         192.0
# HS          18.0
# HY         104.0
# HR         104.0
# YJ          42.0
# SH          24.0
# JS         150.0
# SJ         102.0
# HK         110.0
# healthy      NaN
# Name: healthy, dtype: float64

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['ox'] = np.NAN
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  ox
# 0       16.99  1.01  Female     No  Sun  Dinner     2 NaN
# 1       10.34  1.66    Male     No  Sun  Dinner     3 NaN
# 2       21.01  3.50    Male     No  Sun  Dinner     3 NaN
# 3       23.68  3.31    Male     No  Sun  Dinner     2 NaN
# 4       24.59  3.61  Female     No  Sun  Dinner     4 NaN

# %%
tips['tip'].mean()
# Out:
# 2.9982786885245902

# %%
# 결측치 부분을 메꾸는 방법
test['viewCount'] = test['viewCount'].fillna(test.viewCount.mean())

# %%
tips['ox'] = tips['ox'].fillna(tips['tip'].mean())

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size        ox
# 0       16.99  1.01  Female     No  Sun  Dinner     2  2.998279
# 1       10.34  1.66    Male     No  Sun  Dinner     3  2.998279
# 2       21.01  3.50    Male     No  Sun  Dinner     3  2.998279
# 3       23.68  3.31    Male     No  Sun  Dinner     2  2.998279
# 4       24.59  3.61  Female     No  Sun  Dinner     4  2.998279

# %%
tips['ox'] = np.NAN
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  ox
# 0       16.99  1.01  Female     No  Sun  Dinner     2 NaN
# 1       10.34  1.66    Male     No  Sun  Dinner     3 NaN
# 2       21.01  3.50    Male     No  Sun  Dinner     3 NaN
# 3       23.68  3.31    Male     No  Sun  Dinner     2 NaN
# 4       24.59  3.61  Female     No  Sun  Dinner     4 NaN

# %%
tips3 = tips.dropna(axis=1)
tips3.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.describe()
# Out:
#        total_bill         tip        size   ox
# count  244.000000  244.000000  244.000000  0.0
# mean    19.785943    2.998279    2.569672  NaN
# std      8.902412    1.383638    0.951100  NaN
# min      3.070000    1.000000    1.000000  NaN
# 25%     13.347500    2.000000    2.000000  NaN
# 50%     17.795000    2.900000    2.000000  NaN
# 75%     24.127500    3.562500    3.000000  NaN
# max     50.810000   10.000000    6.000000  NaN

# %%
tips.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000142B40E5C88>,
# ...
#       dtype=object)

# %%
face = ['eye', 'nose', 'ear', 'mouth']

# %%
face[2] = 'ears'
face
# Out:
# ['eye', 'nose', 'ears', 'mouth']

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# # 단변량 그래프 그리기 - 히스토그램

# %% [markdown]
# # 다변량 그래프 그리기

# %% [markdown]
# # 데이터프레임과 시리즈로 그래프 그리기

# %% [markdown]
# # 알아두면 좋아요
